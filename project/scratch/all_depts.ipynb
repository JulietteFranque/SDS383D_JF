# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style as style
from tqdm import tqdm 
tqdm.pandas()
plt.rcParams.update({'axes.labelsize':16})
plt.rcParams.update({'axes.titlesize':16})
plt.rcParams.update({'legend.fontsize':16})
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['lines.linewidth'] = 4
style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/all_depts.csv')

# %%
df
# Out:
#              date  count                                department_name
# 0      2019-02-01     45  Adams County Fire Protection District (90552)
# 1      2019-02-02     43  Adams County Fire Protection District (90552)
# 2      2019-02-03     53  Adams County Fire Protection District (90552)
# 3      2019-02-04     43  Adams County Fire Protection District (90552)
# 4      2019-02-05     52  Adams County Fire Protection District (90552)
# ...           ...    ...                                            ...
# 94541  2022-03-25      0        West Palm Beach Fire Department (99102)
# 94542  2022-03-26      0        West Palm Beach Fire Department (99102)
# 94543  2022-03-27      0        West Palm Beach Fire Department (99102)
# 94544  2022-03-28      0        West Palm Beach Fire Department (99102)
# 94545  2022-03-29      0        West Palm Beach Fire Department (99102)
#
# [94546 rows x 3 columns]

# %%
df = pd.read_csv('../data/fire_counties.csv', encoding='cp1252')

# %%
df
# Out:
#         FDID                            Fire dept name  \
# 0      61014         #9 Area Volunteer Fire Department
# 1       3010  101 Gamaliel Fire Protection District #5
# 2      F3073           104th FW Barnes ANG Fire/Rescue
# 3      36005                   106 Rural Fire District
# 4       4602           11 Point Rural Fire Association
# ...      ...                                       ...
# 27138  79041      Zoar Volunteer Fire Department, Inc.
# 27139  15068               Zoneton Fire District, Inc.
# 27140  79107              Zumbro Falls Fire and Rescue
# 27141  25108        Zumbrota Volunteer Fire Department
# 27142  13010        Zuni Independent Fire District # 8
#
#                       HQ addr1              HQ addr2         HQ city HQ state  \
# 0          FD 115 F Station LN                   NaN         Eufaula       OK
# 1                 5012 101 HWY                   NaN        Gamaliel       AR
# 2                175 Falcon DR  104th FW Barnes ANGB       Westfield       MA
# 3                   PO Box 154                   NaN         Newkirk       OK
# 4      908 E Business RT 60-63                   NaN  Willow Springs       MO
# ...                        ...                   ...             ...      ...
# 27138           190 E 5th ST E                   NaN            Zoar       OH
# 27139       5328 N Preston HWY                   NaN  Shepherdsville       KY
# 27140               PO Box 119                   NaN    Zumbro Falls       MN
# 27141        1500 Jefferson DR                   NaN        Zumbrota       MN
# 27142           04 Third ST NE    13 Old Gallup Road            Zuni       NM
#
#            HQ zip               Mail addr1            Mail addr2 Mail PO box  \
# 0           74432      FD 115 F Station LN                   NaN         NaN
# 1           72537                      NaN                   NaN   PO Box 36
# 2            1085            175 Falcon DR  104th FW Barnes ANGB         NaN
# 3      74647-0154                      NaN                   NaN  PO Box 154
# 4      65793-3432  908 E Business RT 60-63                   NaN         NaN
# ...           ...                      ...                   ...         ...
# 27138       44697                      NaN                   NaN  PO Box 672
# 27139       40165       5328 N Preston HWY                   NaN         NaN
# 27140       55991                      NaN                   NaN  PO Box 119
# 27141       55992                      NaN                   NaN  PO Box 206
# 27142       87327           04 Third ST NE    13 Old Gallup Road  PO Box 339
#
#        ...         Dept Type  \
# 0      ...         Volunteer
# 1      ...         Volunteer
# 2      ...            Career
# 3      ...         Volunteer
# 4      ...         Volunteer
# ...    ...               ...
# 27138  ...         Volunteer
# 27139  ...  Mostly volunteer
# 27140  ...         Volunteer
# 27141  ...         Volunteer
# 27142  ...  Mostly volunteer
#
#                                        Organization Type  \
# 0      Local (includes career, combination, and volun...
# 1      Local (includes career, combination, and volun...
# 2             Federal government (Department of Defense)
# 3      Local (includes career, combination, and volun...
# 4      Local (includes career, combination, and volun...
# ...                                                  ...
# 27138  Local (includes career, combination, and volun...
# 27139  Local (includes career, combination, and volun...
# 27140  Local (includes career, combination, and volun...
# 27141  Local (includes career, combination, and volun...
# 27142  Local (includes career, combination, and volun...
#
#                             Website Number Of Stations  \
# 0                               NaN                  1
# 1                               NaN                  2
# 2                               NaN                  1
# 3                               NaN                  1
# 4                               NaN                  3
# ...                             ...                ...
# 27138         https://zoarfire.com/                  1
# 27139  https://www.zonetonfire.com/                  2
# 27140                           NaN                  1
# 27141                           NaN                  1
# 27142                           NaN                  2
#
#       Active Firefighters - Career Active Firefighters - Volunteer  \
# 0                                0                              15
# 1                                0                              29
# 2                               30                               0
# 3                                0                               8
# 4                                0                              37
# ...                            ...                             ...
# 27138                            0                              14
# 27139                           11                              53
# 27140                            0                              23
# 27141                            0                              30
# 27142                            9                              17
#
#       Active Firefighters - Paid per Call Non-Firefighting - Civilian  \
# 0                                       0                         0.0
# 1                                       0                         0.0
# 2                                       0                         0.0
# 3                                       0                         0.0
# 4                                       0                         0.0
# ...                                   ...                         ...
# 27138                                   0                         0.0
# 27139                                   0                         1.0
# 27140                                   0                         0.0
# 27141                                   0                         0.0
# 27142                                   0                         2.0
#
#       Non-Firefighting - Volunteer  Primary agency for emergency mgmt
# 0                              2.0                                Yes
# 1                              6.0                                 No
# 2                              0.0                                 No
# 3                              2.0                                NaN
# 4                             11.0                                NaN
# ...                            ...                                ...
# 27138                         14.0                                 No
# 27139                         10.0                                Yes
# 27140                          0.0                                NaN
# 27141                          0.0                                 No
# 27142                          6.0                                NaN
#
# [27143 rows x 26 columns]
